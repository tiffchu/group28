# %% [markdown]
# Title <br>
# By Tiffany Chu, Gaurang Ahuja, Nguyen Nguyen, Vienne Lee

# %% [markdown]
# Summary <br>
# - What the data is
# - What we explored
# - How we explored
# - Key findings

# %% [markdown]
# Introduction <br>
# - Context about the data
# - Our key question - something like which features are useful for predicting the species?
# - Overview of the approach

# %% [markdown]
# Methods & Results <br>
# - Load the data
# - Briefly explain the features etc?
# - EDA
#     - plots etc?
#     - scatter plots?
#     - box plots?
# - Modelling
#     - which model works best?
# - Hyperparameter
#     - best parameter?

# %% [markdown]
# Discussion <br>
# - What the results mean?
# - Limitations?
# - Improvements?

# %% [markdown]
# References<br>
# - Documentations we referred to?
# - AI tools?
